# %% [markdown]
# ### data visualization using python, matplotlib and seaborn

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# %matplotlib inline --
# this ensures that the plots are shown and embedded within the jupyter notebook itself. withouth this command, somethimes plots may show up in pop up windows

# %% [markdown]
# ## Line chart

# %% [markdown]
# here is the pyhton list showing the yield of apples(tons per hectare) over 6 years in an imaginary country called kanto

# %%
yield_apples = [0.32,0.54,0.654,0.74,0.324,0.963]

# %% [markdown]
# we can visualize how the yield of apples changes over time using a line chart. to draw a ine chart we can use the `plt.plot` function

# %%
plt.plot(yield_apples)

# %% [markdown]
# calling `plt.plot` function draws the line chart as expected and also return a list of plos drawn `[<matplotlib.lines.Line2D at 0x27f56a9a950>]` shown within the output. we can include a semicolon at the end of the last statement in the cell to avoid showing the output and just display the graph

# %%
plt.plot(yield_apples);

# %% [markdown]
# lets enchance the plot step by step to make it more informative and beautiful

# %% [markdown]
# ### customizing the x axis --
# the x axis of the plot currently shows index from 0 to 5 . the plot would be more imformative if we could show the year for which the data is being plotted. we can do thi sby two arguments

# %%
years = [2010,2011, 2020,2023,2024,2025]
yield_apples = [0.32,0.54,0.654,0.74,0.324,0.963]

# %%
plt.plot(years,yield_apples)

# %% [markdown]
# ### axis lables
#
# we can add labels to the axes to show what each axis represents using plt.xlabel and plt.ylabel methods

# %%
plt.plot(years,yield_apples)
plt.xlabel('Year')
plt.ylabel('Yield (tons per hectare)');

# %% [markdown]
# ### plotting multiple llines

# %%
years = range(2000, 2012)
apples = [0.895, 0.91, 0.919, 0.926, 0.929, 0.931, 0.934, 0.936, 0.937, 0.9375, 0.9372, 0.939]
oranges = [0.962, 0.941, 0.930, 0.923, 0.918, 0.908, 0.907, 0.904, 0.901, 0.898, 0.9, 0.896, ]

# %%
plt.plot(years,apples)
plt.plot(years,oranges)
plt.xlabel('Year')
plt.ylabel('Yield (tons per hectare)');

# %% [markdown]
# ### chart title and legend

# %%
plt.plot(years,apples)
plt.plot(years,oranges)
plt.xlabel('Year')
plt.ylabel('Yield (tons per hectare)');

plt.title("crop yeilds in kanto")
plt.legend(['Apples','Oranges']);

# %% [markdown]
# ### Line markers

# %%
plt.plot(years,apples,marker='o')
plt.plot(years,oranges,marker='x')

plt.xlabel('Year')
plt.ylabel('Yield (tons per hectare)')

plt.title("crop yeilds in kanto")
plt.legend(['Apples','Oranges']);

# %% [markdown]
# ### Styling Lines and Markers
#
# The `plt.plot` function supports many arguments for styling lines and markers:
#
# - `color` or `c`: Set the color of the line ([supported colors](https://matplotlib.org/3.1.0/gallery/color/named_colors.html))
# - `linestyle` or `ls`: Choose between a solid or dashed line
# - `linewidth` or `lw`: Set the width of a line
# - `markersize` or `ms`: Set the size of markers
# - `markeredgecolor` or `mec`: Set the edge color for markers
# - `markeredgewidth` or `mew`: Set the edge width for markers
# - `markerfacecolor` or `mfc`: Set the fill color for markers
# - `alpha`: Opacity of the plot
#
#
# Check out the documentation for `plt.plot` to learn more: [https://matplotlib.org/api/_as_gen/matplotlib.pyplot.plot.html#matplotlib.pyplot.plot](https://matplotlib.org/api/_as_gen/matplotlib.pyplot.plot.html#matplotlib.pyplot.plot) .

# %%
plt.plot(years, apples, marker='s', c='b', ls='-', lw=2, ms=8, mew=2, mec='navy')
plt.plot(years, oranges, marker='o', c='r', ls='--', lw=3, ms=10, alpha=.5)

plt.xlabel('Year')
plt.ylabel('Yield (tons per hectare)')

plt.title("Crop Yields in Kanto")
plt.legend(['Apples', 'Oranges']);

# %% [markdown]
# the fmt argument provides a shorthand for specifying the marker shape,line styple and line color . it can be provided as the third argument to plt.plot
#
# fmt=`[marker][line][color]`

# %%
plt.plot(years,apples,'s--b')
plt.plot(years,oranges,'o-r')

plt.xlabel('year')
plt.ylabel('yield (tons per hectare)')

plt.title("Crop yields in kanato")
plt.legend(['Apples','oranges']);

# %%
plt.plot(years, oranges, 'or')
plt.title("Yield of Oranges (tons per hectare)");

# %% [markdown]
# ### changing the figure size
#
# we cn use `plt.figure` function to chnage the size of the figure

# %%
plt.figure(figsize=(4,3))
plt.plot(years,oranges,'sy');

# %% [markdown]
# ### improving default style using seaborn

# %%
#this made the changes globally ---
# sns.set_style("whitegrid")
sns.set_style("darkgrid")

# %%
plt.plot(years, apples, 's-b')
plt.plot(years, oranges, 'o--r')

plt.xlabel('Year')
plt.ylabel('Yield (tons per hectare)')

plt.title("Crop Yields in Kanto")
plt.legend(['Apples', 'Oranges']);

plt.savefig("crop yields in kanato")

# %% [markdown]
# # scatter plot

# %%
#load data into a pandas dataframe
flowers_df = sns.load_dataset("iris")
#flowers_df = pd.read_csv(csv file)

# %%
flowers_df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
flowers_df.species.unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
flowers_df.sepal_length
# Out:
# 0      5.1
# 1      4.9
# 2      4.7
# 3      4.6
# 4      5.0
#       ...
# 145    6.7
# 146    6.3
# 147    6.5
# 148    6.2
# 149    5.9
# Name: sepal_length, Length: 150, dtype: float64

# %% [markdown]
# here we use line chart, the output is not very informative as there are too many combanications of two properties within hte sataset and there does not seem to be simple relationship between them

# %%
plt.plot(flowers_df.sepal_length,flowers_df.sepal_width);

# %% [markdown]
# we can use scatter plot to visualize how sepal length and width vary using the scatter pllot function from seaborm (imported as sns)

# %%
sns.scatterplot(x=flowers_df.sepal_length, y=flowers_df.sepal_width);

# %%
#adding hues
sns.scatterplot(x=flowers_df.sepal_length, y=flowers_df.sepal_width, hue=flowers_df.species, s=100);

# %%
plt.figure(figsize=(12, 6))
plt.title('Sepal Dimensions')

sns.scatterplot(x=flowers_df.sepal_length, 
                y=flowers_df.sepal_width, 
                hue=flowers_df.species,
                s=100);

# %% [markdown]
# seaborn has inbuilt support for pandas data frames. Instead of passing each column as a series, you can also pass column names and use the data argument to pass the data frame

# %%
plt.title('sepal dimensions')
sns.scatterplot(x='sepal_length',
                'sepal_width',
                hue='species',
                s=100,
                data=flowers_df);
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[53], line 2
#       1 plt.title('sepal dimensions')
# ----> 2 sns.scatterplot('sepal_length',
#       3                 'sepal_width',
#       4                 hue='species',
#       5                 s=100,
#       6                 data=flowers_df)
#
# TypeError: scatterplot() got multiple values for argument 'data'
